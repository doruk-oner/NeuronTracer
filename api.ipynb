# %%
from utility import*

# %%
#useful stuff
source_node = 115

# %%
#load graph 
graph = load_graph_txt("../DemoData/demo_graph.txt")

# %%
#add edge length to edges 
add_edge_length(graph)

# %%
#get neighbors
neighbors = get_neighbors(graph)

# %%
#get bifurcations
get_bifurcations(graph, neighbors)
# Out:
# [30, 77, 85, 93, 105, 106, 129, 132, 143]

# %%
#get locations
get_locs_from_graph(graph, source_node)
# Out:
# [(483.0, 1817.0, 77.0),
#  (480.0, 1823.0, 77.0),
#  (480.0, 1824.0, 77.0),
#  (478.0, 1826.0, 77.0),
#  (476.0, 1830.0, 77.0),
#  (476.0, 1832.0, 77.0),
#  (474.0, 1836.0, 77.0),
#  (473.0, 1837.0, 77.0),
#  (473.0, 1839.0, 77.0),
#  (472.0, 1840.0, 77.0),
#  (472.0, 1842.0, 77.0),
#  (470.0, 1844.0, 77.0),
#  (468.0, 1848.0, 77.0),
#  (467.0, 1850.0, 76.0),
#  (466.0, 1851.0, 76.0),
#  (465.0, 1851.0, 75.0),
#  (461.0, 1855.0, 75.0),
#  (460.0, 1857.0, 76.0),
#  (459.0, 1858.0, 75.0),
#  (458.0, 1857.0, 73.0),
#  (459.0, 1860.0, 77.0),
#  (457.0, 1864.0, 77.0),
#  (456.0, 1863.0, 76.0),
#  (454.0, 1863.0, 76.0),
#  (453.0, 1864.0, 76.0),
#  (452.0, 1865.0, 75.0),
#  (454.0, 1867.0, 77.0),
#  (455.0, 1868.0, 77.0),
#  (457.0, 1866.0, 77.0),
#  (455.0, 1869.0, 77.0),
#  (452.0, 1872.0, 77.0),
#  (452.0, 1873.0, 77.0),
#  (451.0, 1875.0, 76.0),
#  (450.0, 1874.0, 74.0),
#  (451.0, 1872.0, 73.0),
#  (451.0, 1876.0, 77.0),
#  (451.0, 1878.0, 77.0),
#  (450.0, 1880.0, 77.0),
# ...

# %%
#returns leaf nodes
get_leaf_nodes(graph)
# Out:
# [2, 5, 31, 73, 74, 75, 115]

# %%
get_locs_and_index(graph, source_node)
# Out:
# [((483.0, 1817.0, 77.0), 115),
#  ((480.0, 1823.0, 77.0), 116),
#  ((480.0, 1824.0, 77.0), 117),
#  ((478.0, 1826.0, 77.0), 118),
#  ((476.0, 1830.0, 77.0), 119),
#  ((476.0, 1832.0, 77.0), 120),
#  ((474.0, 1836.0, 77.0), 121),
#  ((473.0, 1837.0, 77.0), 122),
#  ((473.0, 1839.0, 77.0), 123),
#  ((472.0, 1840.0, 77.0), 124),
#  ((472.0, 1842.0, 77.0), 125),
#  ((470.0, 1844.0, 77.0), 126),
#  ((468.0, 1848.0, 77.0), 127),
#  ((467.0, 1850.0, 76.0), 99),
#  ((466.0, 1851.0, 76.0), 100),
#  ((465.0, 1851.0, 75.0), 91),
#  ((461.0, 1855.0, 75.0), 92),
#  ((460.0, 1857.0, 76.0), 101),
#  ((459.0, 1858.0, 75.0), 93),
#  ((458.0, 1857.0, 73.0), 73),
#  ((459.0, 1860.0, 77.0), 128),
#  ((457.0, 1864.0, 77.0), 129),
#  ((456.0, 1863.0, 76.0), 103),
#  ((454.0, 1863.0, 76.0), 102),
#  ((453.0, 1864.0, 76.0), 104),
#  ((452.0, 1865.0, 75.0), 94),
#  ((454.0, 1867.0, 77.0), 131),
#  ((455.0, 1868.0, 77.0), 132),
#  ((457.0, 1866.0, 77.0), 130),
#  ((455.0, 1869.0, 77.0), 133),
# ...
